# %%
import pandas as pd
pd.set_option('display.max_columns', None)
from matplotlib import pyplot as plt

# %%
raw = pd.read_csv('ellipseData.csv')

# %%
raw.head()
# Out:
#    clk      posX      posY  BodPosX  BodPosY
# 0    0  0.066846  0.000000      100        0
# 1   31  0.066846  0.000041      100        0
# 2   62  0.066846  0.000083      100        0
# 3   93  0.066846  0.000124      100        0
# 4  124  0.066846  0.000166      100        0

# %%
plt.plot(raw['posX'], raw['posY']) 
plt.plot(0,0, 'ro')
plt.grid()
plt.axis('equal')
# Out:
# (-0.07421882686303116,
#  0.07356323779819235,
#  -0.0738901512663731,
#  0.0738901525051978)

# %%
raw1 = pd.read_csv('ellipseData1.csv')
plt.plot(raw1['posX'], raw1['posY']) 
plt.plot(0,0, 'ro')
plt.grid()
plt.axis('equal')
# Out:
# (-0.11879393897238462,
#  0.00565685423678022,
#  -0.12351346432459914,
#  0.12168735504354394)

# %%
raw1 = pd.read_csv('hyperBolicData.csv')
plt.plot(raw1['posX'], raw1['posY']) 
plt.plot(0,0, 'ro')
plt.grid()
plt.axis('equal')
# Out:
# (-0.45549941187796356,
#  0.09171945613223675,
#  -0.06519431399149024,
#  1.369080593821295)

# %%
raw1.head()
# Out:
#    clk      posX      posY  BodPosX  BodPosY
# 0    0  0.066846  0.000000      100        0
# 1   75  0.066846  0.000000      100        0
# 2  150  0.066846  0.000191      100        0
# 3  225  0.066846  0.000381      100        0
# 4  300  0.066845  0.000572      100        0

# %%
raw.head()
# Out:
#    clk      posX      posY  BodPosX  BodPosY
# 0    0  0.066846  0.000000      100        0
# 1   31  0.066846  0.000041      100        0
# 2   62  0.066846  0.000083      100        0
# 3   93  0.066846  0.000124      100        0
# 4  124  0.066846  0.000166      100        0

# %%
raw2 = pd.read_csv('ellSun.csv')
raw3 = pd.read_csv('ellpl1.csv')
xx = 8000
plt.plot(raw2['posX'][:xx], raw2['posY'][:xx])
plt.plot(raw3['posX'][:xx], raw3['posY'][:xx]) 
# plt.plot(0,0, 'ro')
plt.grid()
plt.axis('equal')
# Out:
# (-400.32833155368553,
#  123.82515541843433,
#  -118.8561858685007,
#  295.9799435573462)

# %%
raw2.head()
# Out:
#       clk       posX       posY  BodPosX  BodPosY
# 0  314475  98.976114  13.870015        0        0
# 1  320282  99.005091  14.179588        0        0
# 2  326089  99.033470  14.489076        0        0
# 3  331896  99.061251  14.798477        0        0
# 4  337703  99.088435  15.107789        0        0

# %%
raw2['delt'] = raw2['posX'].diff()

# %%
raw2.head(30)
# Out:
#        clk       posX       posY  BodPosX  BodPosY      delt
# 0   314475  98.976114  13.870015        0        0       NaN
# 1   320282  99.005091  14.179588        0        0  0.028977
# 2   326089  99.033470  14.489076        0        0  0.028378
# 3   331896  99.061251  14.798477        0        0  0.027781
# 4   337703  99.088435  15.107789        0        0  0.027184
# 5   343510  99.115024  15.417009        0        0  0.026589
# 6   349317  99.141019  15.726138        0        0  0.025995
# 7   355124  99.166421  16.035172        0        0  0.025402
# 8   360931  99.191231  16.344110        0        0  0.024810
# 9   366738  99.215450  16.652952        0        0  0.024219
# 10  372545  99.239080  16.961694        0        0  0.023630
# 11  378352  99.262121  17.270336        0        0  0.023041
# 12  384159  99.284575  17.578875        0        0  0.022454
# 13  389966  99.306443  17.887311        0        0  0.021868
# ...
